# %%
import plotly.express as px
import pandas as pd

# %%
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()

# %%
data_pkl = "outputs/final_reconstituted 24-08-28.pkl"
all_data = pd.read_pickle(data_pkl)
all_data
# Out:
#               start_time     completion_time  star_rating  \
# 0    2024-03-20 13:45:57 2024-03-20 13:47:45         <NA>
# 1    2024-03-20 14:00:18 2024-03-20 14:02:21            5
# 2    2024-03-20 14:27:17 2024-03-20 14:28:30            4
# 3    2024-03-20 14:27:17 2024-03-20 14:28:48            5
# 4    2024-03-20 14:27:32 2024-03-20 14:28:52            5
# ...                  ...                 ...          ...
# 5834 2024-04-08 16:06:24 2024-04-08 16:25:14            4
# 5835 2024-04-09 08:00:24 2024-04-09 08:01:21            5
# 5836 2024-04-09 08:45:35 2024-04-09 08:53:33            5
# 5837 2024-04-09 09:56:55 2024-04-09 09:59:45            5
# 5838 2024-04-09 10:18:58 2024-04-09 10:22:53            5
#
#                                          txt_what_liked  \
# 0                                                  none
# 1                              The Team who organise it
# 2                         well organised great helpers
# ...

# %%
fig = px.histogram(all_data, x="star_rating", title = "Star Ratings")
fig.show()
